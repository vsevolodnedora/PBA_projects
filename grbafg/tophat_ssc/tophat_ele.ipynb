# %%
import numpy as np
import h5py
import pandas as pd
from glob import glob
import os
import re
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
# settings
color_pal = sns.color_palette()
plt.style.use("fivethirtyeight")

np.set_printoptions(precision=2)

from IPython.display import clear_output

# grb codes
import PyBlastAfterglowMag as PBA
try:
    import afterglowpy as grb
except:
    afterglowpy = False
    print("Error! could not import afteglowpy")

# %% [markdown]
# # Jet Settings (TopHat)

# %%
workingdir = os.getcwd()+'/'
pba_src = "/home/vsevolod/Work/GIT/GitHub/PyBlastAfterglowMag/src/pba.out"
loglevel= "info"
structure = {
    "struct":"tophat",
    "Eiso_c":1.e52, "Gamma0c": 300., "M0c": -1.,
    "theta_c": 0.3, "theta_w": 0.3, "nlayers_pw": 80, "nlayers_a": 1
}

# %%
# run code 
def make_runs():

    PBA.parfile_tools.modify_parfile_par_opt(workingdir=workingdir, part="grb",keep_old=False,newparfile="parfile.par",
                                             newpars={},newopts={"method_synchrotron":"Joh06",
                                                                 "method_shock_ele":"analytic",
                                                                 "method_ssc":"none",
                                                                 "method_ne" :"useNe", # useNe
                                                                 "method_eats":"piece-wise",
                                                                 "method_comp_mode": "observFlux",
                                                                 "fname_light_curve":"lc_syn.h5",
                                                                 "fname_spectrum":"spec_syn.h5"})
    pba_id = PBA.id_analytic.JetStruct(n_layers_pw=structure["nlayers_pw"], n_layers_a=structure["nlayers_a"])
    pba_id.save_1d_id(*pba_id.get_1D_id(pars=structure, type="piece-wise"), outfpath=workingdir+"grb_id.h5")
    pba0 = PBA.interface.PyBlastAfterglow(workingdir=workingdir, readparfileforpaths=True, parfile="parfile.par")
    pba0.run(path_to_cpp_executable=pba_src,loglevel=loglevel)
    clear_output(wait=False)
    
    PBA.parfile_tools.modify_parfile_par_opt(workingdir=workingdir, part="grb",keep_old=False,newparfile="parfile.par",
                                             newpars={},newopts={"method_synchrotron":"Dermer09",
                                                                 "method_shock_ele":"analytic",
                                                                 "method_ssc":"none",
                                                                 "method_ne" :"useNe", # useNe
                                                                 "method_eats":"adaptive",
                                                                 "method_comp_mode": "comovSpec",
                                                                 "fname_light_curve":"lc_syn.h5",
                                                                 "fname_spectrum":"spec_syn.h5"})
    pba_id = PBA.id_analytic.JetStruct(n_layers_pw=structure["nlayers_pw"], n_layers_a=structure["nlayers_a"])
    pba_id.save_1d_id(*pba_id.get_1D_id(pars=structure, type="adaptive"), outfpath=workingdir+"grb_id.h5")
    pba = PBA.interface.PyBlastAfterglow(workingdir=workingdir, readparfileforpaths=True, parfile="parfile.par")
    pba.run(path_to_cpp_executable=pba_src,loglevel=loglevel)
    clear_output(wait=False)


    PBA.parfile_tools.modify_parfile_par_opt(workingdir=workingdir, part="grb",keep_old=False,newparfile="parfile.par",
                                             newpars={},newopts={"method_synchrotron":"GSL",
                                                                 "method_shock_ele":"numeric",
                                                                 "method_ssc":"none",
                                                                 "method_ne" :"useNe", # useNe
                                                                 "method_eats":"adaptive",
                                                                 "method_comp_mode": "comovSpec",
                                                                 "fname_light_curve":"lc_ssc.h5",
                                                                 "fname_spectrum":"spec_ssc.h5"})
    pba_id = PBA.id_analytic.JetStruct(n_layers_pw=structure["nlayers_pw"], n_layers_a=structure["nlayers_a"])
    pba_id.save_1d_id(*pba_id.get_1D_id(pars=structure, type="adaptive"), outfpath=workingdir+"grb_id.h5")
    pba_num = PBA.interface.PyBlastAfterglow(workingdir=workingdir, readparfileforpaths=True, parfile="parfile.par")
    pba_num.run(path_to_cpp_executable=pba_src,loglevel=loglevel)
    # clear_output(wait=False)
    
    return (pba0, pba, pba_num)
def plot_runs(pba0,pba1, pba2):
    
    
    
    obs_freq=1e9
    
    print(pba2.GRB.get_lc_totalflux(freq=obs_freq,time=None,spec=False))
    fig, ax = plt.subplots(ncols=1, nrows=1)
    
    ax.plot(pba0.GRB.get_lc_times(spec=False,unique=True),
            pba0.GRB.get_lc_totalflux(freq=obs_freq,time=None,spec=False),
            color="green",label="piece-wise")
    ax.plot(pba1.GRB.get_lc_times(spec=False,unique=True),
            pba1.GRB.get_lc_totalflux(freq=obs_freq,time=None,spec=False),
            color="green",label="Analytic")
    ax.plot(pba2.GRB.get_lc_times(spec=False,unique=True),
            pba2.GRB.get_lc_totalflux(freq=obs_freq,time=None,spec=False),
            color="blue",label="Numeric")
    ax.set_xlabel("time [s]")
    ax.set_ylabel("Flux [mJy]")
    ax.set_xscale("log")
    ax.set_yscale("log")
    # ax.set_ylim(pba1.GRB.get_lc_totalflux(freq=obs_freq,time=None,spec=False).max()*1e-5,
    #             pba1.GRB.get_lc_totalflux(freq=obs_freq,time=None,spec=False).max()*1e2)
    ax.legend()
    plt.title("Radio light curves for Top-Hat jet")
    plt.tight_layout()
    plt.show()
    
plot_runs(*make_runs())
# Out:
# [ INFO    ] : [ main.cpp:152 ] : Computation tgrid = [100, 9.63829e+17] n=1000
# [ INFO    ] : [ main.cpp:153 ] : Output      tgrid = [100, 9.63829e+17] n=1000
# [ INFO    ] : [ model_magnetar.h:569 ] : Magnetar is not initialized and will not be considered.
# [ INFO    ] : [ ejecta_id.h:206 ] :  1D ID has theta_wing=0.3 theta_core=0.3
# [ INFO    ] : [ ejecta_id.h:258 ] : Initial data loaded with nshells=1 m_nlayers=1
# [ INFO    ] : [ ejecta_id.h:280 ] : Angular grids are initialized. nshells=1 m_nlayers=1
# [ INFO    ] : [ ejecta_id.h:303 ] : Energy and mass are rescaled.
# [ WARNING ] : [ blastwave_base.h:104 ] : Parameter theta_max not given. Using default value=1.5708
# [ WARNING ] : [ blastwave_base.h:107 ] : Parameter epsilon_e_rad not given. Using default value=0
# [ WARNING ] : [ blastwave_radiation.h:975 ] : Parameter theta_max not given. Using default value=1.5708
# [ WARNING ] : [ blastwave_radiation.h:982 ] : Parameter theta_max not given. Using default value=1.5708
# [ WARNING ] : [ eats.h:933 ] : Parameter nmax_phi not given. Using default value=1000
# [ WARNING ] : [ eats.h:934 ] : Parameter nmax_theta not given. Using default value=1000
# [ WARNING ] : [ eats.h:935 ] : Parameter rtol_theta not given. Using default value=0.01
# [ WARNING ] : [ eats.h:936 ] : Parameter rtol_phi not given. Using default value=0.01
# [ WARNING ] : [ eats.h:937 ] : Parameter atol_theta not given. Using default value=0.01
# [ WARNING ] : [ eats.h:938 ] : Parameter atol_phi not given. Using default value=0.01
# [ WARNING ] : [ eats.h:943 ] : Option counter_jet not given. Using default value=1
# [ WARNING ] : [ radiation.h:1024 ] : Parameter mu not given. Using default value=0.62
# [ WARNING ] : [ radiation.h:1025 ] : Parameter mu_e not given. Using default value=1.18
# [ WARNING ] : [ radiation.h:1026 ] : Parameter beta_min not given. Using default value=1e-05
# [ WARNING ] : [ radiation.h:1027 ] : Parameter gamma_max not given. Using default value=1e+07
# [ WARNING ] : [ radiation.h:1029 ] : Option limit_lf_min_to1 not given. Using default value=0
# [ WARNING ] : [ radiation.h:1146 ] :  Option for method_nonreldist is not set. Using default value.
# [ WARNING ] : [ radiation.h:1196 ] :  Option for 'method_Bsh' is not set. Using default value.
# [ WARNING ] : [ radiation.h:1220 ] :  Option for 'method_lf_max' is not set. Using default value.
# [ INFO    ] : [ radiation.h:1876 ] :  allocating comoving spectrum array (fs)  freqs=200 by radii=1000 Spec. grid=200000
# [ WARNING ] : [ ejecta_base.h:342 ] : Option do_eninj_inside_rhs not given. Using default value=1
# [ INFO    ] : [ ejecta_base.h:344 ] : finished initializing ejecta. nshells=1 nlayers=1
# [ INFO    ] : [ ejecta_base.h:190 ] : ejecta is not initialized and will not be considered.
# [ INFO    ] : [ ejecta_base.h:190 ] : ejecta is not initialized and will not be considered.
# [ INFO    ] : [ model_magnetar.h:1870 ] : PWN is not initialized and will not be considered.
# [ INFO    ] : [ main.cpp:339 ] : Finished reading parfile [0.00244078 s]
# [ INFO    ] : [ model_evolve.h:73 ] :  ODE will solve N_mag=0 N_grb=22 N_ej=0 N_ej_pwn2=0 N_ej_pwn=0 (total 22) equations.
# [ INFO    ] : [ model_evolve.h:219 ] : Initializing GRB blastwaves with  nlayers=1 nshells=1
# [ INFO    ] : [ main.cpp:173 ] : all initial conditions set. Starting evolution
# [ INFO    ] : [ model_evolve.h:499 ] : it=10/1000 t=1.45e+02 s, 1.67e-03 d [Solver=3.91e-06 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=20/1000 t=2.09e+02 s, 2.42e-03 d [Solver=5.68e-06 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=30/1000 t=3.02e+02 s, 3.50e-03 d [Solver=2.04e-05 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=40/1000 t=4.37e+02 s, 5.05e-03 d [Solver=8.16e-06 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=50/1000 t=6.31e+02 s, 7.30e-03 d [Solver=8.18e-06 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=60/1000 t=9.12e+02 s, 1.06e-02 d [Solver=8.40e-06 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=70/1000 t=1.32e+03 s, 1.53e-02 d [Solver=9.91e-06 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=80/1000 t=1.91e+03 s, 2.21e-02 d [Solver=6.75e-06 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=90/1000 t=2.75e+03 s, 3.19e-02 d [Solver=6.73e-06 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=100/1000 t=3.98e+03 s, 4.61e-02 d [Solver=6.74e-06 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=110/1000 t=5.75e+03 s, 6.66e-02 d [Solver=6.69e-06 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=120/1000 t=8.32e+03 s, 9.63e-02 d [Solver=6.74e-06 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=130/1000 t=1.20e+04 s, 1.39e-01 d [Solver=6.75e-06 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=140/1000 t=1.74e+04 s, 2.01e-01 d [Solver=8.01e-06 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=150/1000 t=2.51e+04 s, 2.91e-01 d [Solver=7.43e-06 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=160/1000 t=3.63e+04 s, 4.20e-01 d [Solver=7.65e-06 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=170/1000 t=5.25e+04 s, 6.07e-01 d [Solver=7.45e-06 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=180/1000 t=7.59e+04 s, 8.78e-01 d [Solver=7.44e-06 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=190/1000 t=1.10e+05 s, 1.27e+00 d [Solver=8.59e-06 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=200/1000 t=1.58e+05 s, 1.83e+00 d [Solver=8.59e-06 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=210/1000 t=2.29e+05 s, 2.65e+00 d [Solver=8.58e-06 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=220/1000 t=3.31e+05 s, 3.83e+00 d [Solver=8.76e-06 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=230/1000 t=4.79e+05 s, 5.54e+00 d [Solver=9.01e-06 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=240/1000 t=6.92e+05 s, 8.01e+00 d [Solver=9.01e-06 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=250/1000 t=1.00e+06 s, 1.16e+01 d [Solver=1.03e-05 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=260/1000 t=1.45e+06 s, 1.67e+01 d [Solver=1.02e-05 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=270/1000 t=2.09e+06 s, 2.42e+01 d [Solver=1.03e-05 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=280/1000 t=3.02e+06 s, 3.50e+01 d [Solver=1.02e-05 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=290/1000 t=4.37e+06 s, 5.05e+01 d [Solver=1.09e-05 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=300/1000 t=6.31e+06 s, 7.30e+01 d [Solver=1.22e-05 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=310/1000 t=9.12e+06 s, 1.06e+02 d [Solver=1.22e-05 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=320/1000 t=1.32e+07 s, 1.53e+02 d [Solver=1.22e-05 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=330/1000 t=1.91e+07 s, 2.21e+02 d [Solver=1.22e-05 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=340/1000 t=2.75e+07 s, 3.19e+02 d [Solver=1.22e-05 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=350/1000 t=3.98e+07 s, 4.61e+02 d [Solver=1.46e-05 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=360/1000 t=5.75e+07 s, 6.66e+02 d [Solver=1.45e-05 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=370/1000 t=8.32e+07 s, 9.63e+02 d [Solver=1.45e-05 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=380/1000 t=1.20e+08 s, 1.39e+03 d [Solver=1.45e-05 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=390/1000 t=1.74e+08 s, 2.01e+03 d [Solver=1.45e-05 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=400/1000 t=2.51e+08 s, 2.91e+03 d [Solver=2.54e-05 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=410/1000 t=3.63e+08 s, 4.20e+03 d [Solver=2.79e-05 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=420/1000 t=5.25e+08 s, 6.07e+03 d [Solver=1.82e-05 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=430/1000 t=7.59e+08 s, 8.78e+03 d [Solver=1.73e-05 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=440/1000 t=1.10e+09 s, 1.27e+04 d [Solver=1.60e-05 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=450/1000 t=1.58e+09 s, 1.83e+04 d [Solver=1.60e-05 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=460/1000 t=2.29e+09 s, 2.65e+04 d [Solver=1.60e-05 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=470/1000 t=3.31e+09 s, 3.83e+04 d [Solver=1.74e-05 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=480/1000 t=4.79e+09 s, 5.54e+04 d [Solver=1.65e-05 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=490/1000 t=6.92e+09 s, 8.01e+04 d [Solver=1.65e-05 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=500/1000 t=1.00e+10 s, 1.16e+05 d [Solver=1.66e-05 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=510/1000 t=1.45e+10 s, 1.67e+05 d [Solver=1.66e-05 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=520/1000 t=2.09e+10 s, 2.42e+05 d [Solver=1.65e-05 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=530/1000 t=3.02e+10 s, 3.50e+05 d [Solver=1.79e-05 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=540/1000 t=4.37e+10 s, 5.05e+05 d [Solver=1.60e-05 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=550/1000 t=6.31e+10 s, 7.30e+05 d [Solver=1.60e-05 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=560/1000 t=9.12e+10 s, 1.06e+06 d [Solver=1.60e-05 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=570/1000 t=1.32e+11 s, 1.53e+06 d [Solver=1.59e-05 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=580/1000 t=1.91e+11 s, 2.21e+06 d [Solver=1.72e-05 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=590/1000 t=2.75e+11 s, 3.19e+06 d [Solver=2.31e-05 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=600/1000 t=3.98e+11 s, 4.61e+06 d [Solver=2.44e-05 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=610/1000 t=5.75e+11 s, 6.66e+06 d [Solver=2.44e-05 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=620/1000 t=8.32e+11 s, 9.63e+06 d [Solver=2.44e-05 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=630/1000 t=1.20e+12 s, 1.39e+07 d [Solver=2.45e-05 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=640/1000 t=1.74e+12 s, 2.01e+07 d [Solver=2.43e-05 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=650/1000 t=2.51e+12 s, 2.91e+07 d [Solver=2.56e-05 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=660/1000 t=3.63e+12 s, 4.20e+07 d [Solver=2.57e-05 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=670/1000 t=5.25e+12 s, 6.07e+07 d [Solver=2.63e-05 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=680/1000 t=7.59e+12 s, 8.78e+07 d [Solver=2.76e-05 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=690/1000 t=1.10e+13 s, 1.27e+08 d [Solver=2.76e-05 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=700/1000 t=1.58e+13 s, 1.83e+08 d [Solver=2.76e-05 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=710/1000 t=2.29e+13 s, 2.65e+08 d [Solver=2.76e-05 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=720/1000 t=3.31e+13 s, 3.83e+08 d [Solver=2.88e-05 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=730/1000 t=4.79e+13 s, 5.54e+08 d [Solver=2.87e-05 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=740/1000 t=6.92e+13 s, 8.01e+08 d [Solver=2.93e-05 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=750/1000 t=1.00e+14 s, 1.16e+09 d [Solver=3.44e-05 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=760/1000 t=1.45e+14 s, 1.67e+09 d [Solver=3.43e-05 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=770/1000 t=2.09e+14 s, 2.42e+09 d [Solver=3.59e-05 s]
# [ INFO    ] : [ model_evolve.h:499 ] : it=780/1000 t=3.02e+14 s,
